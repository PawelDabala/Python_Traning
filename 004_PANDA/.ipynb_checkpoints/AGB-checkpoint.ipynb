# %%
import pandas as pd
from datetime import datetime, time, timedelta

# %%
df = pd.read_excel('plik kampanii Skoda Octavia.xlsx', sheet_name='AGB')

# %%
df.tail()
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count  Channel  \
# 8218 2020-09-17  21:48:00  2nd last        7          8  Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9  Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19  Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17  Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17  Zoom TV
#
#                                               Film Code  \
# 8218  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 8219  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 8220  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 8221  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 8222  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
#
#                                           Prog Campaign  \
# 8218                        CHICAGO P.D. /SER.KRYM.USA/
# 8219                             Z ARCHIWUM X /SER.USA/
# 8220         HITY POLSKIEGO KABARETU /PROG.ROZRYW.POL./
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   datetime64[ns]
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   object
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   object
#  6   Film Code                 8223 non-null   object
#  7   Prog Campaign             8223 non-null   object
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 3.8 MB

# %%
len(df)
# Out:
# 8223

# %%
df.Channel.nunique()
# Out:
# 117

# %%
df.Channel.value_counts()
# Out:
# Extreme Sports          361
# TVN24                   243
# Polsat Sport News HD    211
# Gametoon                183
# Travel Channel          179
#                        ...
# E!Entertainment          15
# BBC CBeebies             11
# Scifi Universal           6
# TVP1                      5
# Animal Planet HD          1
# Name: Channel, Length: 117, dtype: int64

# %%
df.Channel = df.Channel.astype('category')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   datetime64[ns]
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   object
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   category
#  6   Film Code                 8223 non-null   object
#  7   Prog Campaign             8223 non-null   object
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(2), object(4)
# memory usage: 3.2 MB

# %%
df.Date.nunique()
# Out:
# 20

# %%
df.Date = df.Date.astype('category')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   category
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   object
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   category
#  6   Film Code                 8223 non-null   object
#  7   Prog Campaign             8223 non-null   object
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
# dtypes: category(2), float64(3), int64(2), object(4)
# memory usage: 3.2 MB

# %%
df.head()
# Out:
#         Date      Time PIB rel  PIB pos  PIB count   Channel  \
# 0 2020-09-01  17:26:00   First        1         10  13 Ulica
# 1 2020-09-01  18:42:00     2nd        2         11  13 Ulica
# 2 2020-09-01  18:43:00     2nd        2         11  13 Ulica
# 3 2020-09-01  18:44:00     2nd        2         11  13 Ulica
# 4 2020-09-01  18:57:00    Last       11         11  13 Ulica
#
#                                            Film Code  \
# 0  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 2  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 3  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 4  Skoda octavia/ niebieskie auto/ kreta droga/ n...
#
#                         Prog Campaign  A 25-69 HHI3500+ (Skoda)  \
# 0  COBRA ODDZIAL SPECJALNY/SER.NIEM./                      0.00
# 1       DOWODY ZBRODNI /SER.SENS.USA/                      0.07
# 2       DOWODY ZBRODNI /SER.SENS.USA/                      0.07
# ...

# %%
df['PIB rel'] = df['PIB rel'].astype('category')

# %%
df['Film Code'] = df['Film Code'].astype('category')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   category
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   category
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   category
#  6   Film Code                 8223 non-null   category
#  7   Prog Campaign             8223 non-null   object
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
# dtypes: category(4), float64(3), int64(2), object(2)
# memory usage: 1.4 MB

# %%
df['Prog Campaign'].value_counts()
# Out:
# STREAM NATION /MAG.KOMP./                        116
# PORANEK W TVN 24                                 101
# LIGA NARODOW /MECZ PILKI NOZNEJ/                 100
# GORACE PYTANIA /PROG.PUBL.POL./                   71
# VOX MUSIC TV                                      68
#                                                 ...
# MALOMIASTECZKOWE SWIETA /FILM DRAM.OBYCZ.USA/      1
# BETTY I CORETTA /FILM DRA.BIO.USA/                 1
# OBSESJA NISZCZY MI ZYCIE /SER.DOK.USA/             1
# KOSZMAR ZONY /FILM DRA.USA/                        1
# SKOK /FILM SENS.KAN.USA/                           1
# Name: Prog Campaign, Length: 2011, dtype: int64

# %%
df['Prog Campaign'] = df['Film Code'].astype('category')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   category
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   category
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   category
#  6   Film Code                 8223 non-null   category
#  7   Prog Campaign             8223 non-null   category
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
# dtypes: category(5), float64(3), int64(2), object(1)
# memory usage: 763.1 KB

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'PIB rel', 'PIB pos', 'PIB count', 'Channel',
#        'Film Code', 'Prog Campaign', 'A 25-69 HHI3500+ (Skoda)',
#        'A 16-49 (Others)', 'A 16-59 (Others)'],
#       dtype='object')

# %%
df.sort_values(by=['Channel', 'Date'])
# Out:
#            Date                 Time PIB rel  PIB pos  PIB count  \
# 0    2020-09-01             17:26:00   First        1         10
# 1    2020-09-01             18:42:00     2nd        2         11
# 2    2020-09-01             18:43:00     2nd        2         11
# 3    2020-09-01             18:44:00     2nd        2         11
# 4    2020-09-01             18:57:00    Last       11         11
# ...         ...                  ...     ...      ...        ...
# 4468 2020-09-20             02:10:00  Middle       11         14
# 4469 2020-09-20             11:22:00  Middle        6         12
# 4470 2020-09-20             13:50:00  Middle        7         15
# 4471 2020-09-20             18:41:00  Middle        5         11
# 4472 2020-09-20  1900-01-01 01:46:00  Middle       11         14
#
#                Channel                                          Film Code  \
# 0             13 Ulica  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# ...

# %%
df.loc[4472, 'Time']
# Out:
# datetime.datetime(1900, 1, 1, 1, 46)

# %%
df.loc[0, 'Time']
# Out:
# datetime.time(17, 26)

# %%
type(df.loc[0, 'Time'])
# Out:
# datetime.time

# %%
isinstance(df.loc[0, 'Time'], time)
# Out:
# True

# %%
isTime = df.Time == isinstance(df.Time, time)

# %%
isTime
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8218    False
# 8219    False
# 8220    False
# 8221    False
# 8222    False
# Name: Time, Length: 8223, dtype: bool

# %%
df[isTime]
# Out:
# Empty DataFrame
# Columns: [Date, Time, PIB rel, PIB pos, PIB count, Channel, Film Code, Prog Campaign, A 25-69 HHI3500+ (Skoda), A 16-49 (Others), A 16-59 (Others)]
# Index: []

# %%
df.Time
# Out:
# 0       17:26:00
# 1       18:42:00
# 2       18:43:00
# 3       18:44:00
# 4       18:57:00
#           ...
# 8218    21:48:00
# 8219    18:20:00
# 8220    17:27:00
# 8221    19:26:00
# 8222    21:35:00
# Name: Time, Length: 8223, dtype: object

# %%
def isTime(row):
    vtime = row['Time']
    return True if isinstance(vtime, time) else False

# %%
df['IsTime'] = df.apply(isTime, axis=1)

# %%
df
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
df.IsTime == False
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8218    False
# 8219    False
# 8220    False
# 8221    False
# 8222    False
# Name: IsTime, Length: 8223, dtype: bool

# %%
df[df.IsTime == False]
# Out:
#            Date                 Time PIB rel  PIB pos  PIB count  \
# 189  2020-09-12  1900-01-01 01:16:00  Middle       11         15
# 227  2020-09-03  1900-01-01 00:29:00  Middle       10         20
# 228  2020-09-03  1900-01-01 01:27:00  Middle        8         19
# 292  2020-09-10  1900-01-01 00:26:00  Middle        4         19
# 364  2020-09-15  1900-01-01 01:51:00  Middle       15         18
# ...         ...                  ...     ...      ...        ...
# 7910 2020-09-10  1900-01-01 01:35:00  Middle        3         13
# 7926 2020-09-17  1900-01-01 01:31:00  Middle        4         17
# 8118 2020-09-19  1900-01-01 01:25:00  Middle       15         17
# 8134 2020-09-02  1900-01-01 00:21:00  Middle        9         16
# 8156 2020-09-04  1900-01-01 01:47:00  Middle        4          8
#
#                    Channel                                          Film Code  \
# 189             4FUN DANCE  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# ...

# %%
datetime.now() + timedelta(days=1)
# Out:
# datetime.datetime(2021, 12, 16, 14, 39, 29, 230389)

# %%
tdf = df.copy()

# %%
tdf
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
tdf[tdf.IsTime is False] = tdf.Date + timedelta(days=1)

# %%
tdf.Date = pd.to_datetime(tdf.Date)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   category
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   category
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   category
#  6   Film Code                 8223 non-null   category
#  7   Prog Campaign             8223 non-null   category
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
#  11  IsTime                    8223 non-null   bool
# dtypes: bool(1), category(5), float64(3), int64(2), object(1)
# memory usage: 439.9+ KB

# %%
tdf.Date = tdf.Date.astype('datetime64[ns]')

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   datetime64[ns]
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   category
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   category
#  6   Film Code                 8223 non-null   category
#  7   Prog Campaign             8223 non-null   category
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
#  11  IsTime                    8223 non-null   bool
# dtypes: bool(1), category(4), datetime64[ns](1), float64(3), int64(2), object(1)
# ...

# %%
tdf[tdf.IsTime == False]
# Out:
#            Date                 Time PIB rel  PIB pos  PIB count  \
# 189  2020-09-12  1900-01-01 01:16:00  Middle       11         15
# 227  2020-09-03  1900-01-01 00:29:00  Middle       10         20
# 228  2020-09-03  1900-01-01 01:27:00  Middle        8         19
# 292  2020-09-10  1900-01-01 00:26:00  Middle        4         19
# 364  2020-09-15  1900-01-01 01:51:00  Middle       15         18
# ...         ...                  ...     ...      ...        ...
# 7910 2020-09-10  1900-01-01 01:35:00  Middle        3         13
# 7926 2020-09-17  1900-01-01 01:31:00  Middle        4         17
# 8118 2020-09-19  1900-01-01 01:25:00  Middle       15         17
# 8134 2020-09-02  1900-01-01 00:21:00  Middle        9         16
# 8156 2020-09-04  1900-01-01 01:47:00  Middle        4          8
#
#                    Channel                                          Film Code  \
# 189             4FUN DANCE  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# ...

# %%
tdf.head()
# Out:
#         Date      Time PIB rel  PIB pos  PIB count   Channel  \
# 0 2020-09-01  17:26:00   First        1         10  13 Ulica
# 1 2020-09-01  18:42:00     2nd        2         11  13 Ulica
# 2 2020-09-01  18:43:00     2nd        2         11  13 Ulica
# 3 2020-09-01  18:44:00     2nd        2         11  13 Ulica
# 4 2020-09-01  18:57:00    Last       11         11  13 Ulica
#
#                                            Film Code  \
# 0  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 2  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 3  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 4  Skoda octavia/ niebieskie auto/ kreta droga/ n...
#
#                                        Prog Campaign  \
# 0  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 2  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# 3  Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
tdf.columns
# Out:
# Index([                    'Date',                     'Time',
#                         'PIB rel',                  'PIB pos',
#                       'PIB count',                  'Channel',
#                       'Film Code',            'Prog Campaign',
#        'A 25-69 HHI3500+ (Skoda)',         'A 16-49 (Others)',
#                'A 16-59 (Others)',                   'IsTime',
#                             False],
#       dtype='object')

# %%
def addOneDay(row):
#     print(row['IsTime'])
    if row['IsTime'] == False:
        print(type(row['Date'] + timedelta(days=1)))

# %%
tdf = df.copy()

# %%
tdf
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
tdf
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
tdf['ShiftDate'] = tdf.Date + pd.Timedelta(days=1)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8223 entries, 0 to 8222
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8223 non-null   datetime64[ns]
#  1   Time                      8223 non-null   object
#  2   PIB rel                   8223 non-null   category
#  3   PIB pos                   8223 non-null   int64
#  4   PIB count                 8223 non-null   int64
#  5   Channel                   8223 non-null   category
#  6   Film Code                 8223 non-null   category
#  7   Prog Campaign             8223 non-null   category
#  8   A 25-69 HHI3500+ (Skoda)  8223 non-null   float64
#  9   A 16-49 (Others)          8223 non-null   float64
#  10  A 16-59 (Others)          8223 non-null   float64
#  11  IsTime                    8223 non-null   bool
# dtypes: bool(1), category(4), datetime64[ns](1), float64(3), int64(2), object(1)
# ...

# %%
tdf.Date = tdf.Date.astype('datetime64[ns]')

# %%
tdf
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
del tdf['ShiftDate']

# %%
tdf
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
def addOneDay(row):
    return row.Date + pd.Timedelta(days=1) if row['IsTime'] == False else row.Date

# %%
tdf['ShiftData'] = tdf.apply(addOneDay, axis=1)

# %%
tdf
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...

# %%
tdf[tdf.IsTime == False]
# Out:
#            Date                 Time PIB rel  PIB pos  PIB count  \
# 189  2020-09-12  1900-01-01 01:16:00  Middle       11         15
# 227  2020-09-03  1900-01-01 00:29:00  Middle       10         20
# 228  2020-09-03  1900-01-01 01:27:00  Middle        8         19
# 292  2020-09-10  1900-01-01 00:26:00  Middle        4         19
# 364  2020-09-15  1900-01-01 01:51:00  Middle       15         18
# ...         ...                  ...     ...      ...        ...
# 7910 2020-09-10  1900-01-01 01:35:00  Middle        3         13
# 7926 2020-09-17  1900-01-01 01:31:00  Middle        4         17
# 8118 2020-09-19  1900-01-01 01:25:00  Middle       15         17
# 8134 2020-09-02  1900-01-01 00:21:00  Middle        9         16
# 8156 2020-09-04  1900-01-01 01:47:00  Middle        4          8
#
#                    Channel                                          Film Code  \
# 189             4FUN DANCE  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# ...

# %%
tdf.Time = tdf.Time.astype('datetime64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11768/596292963.py in <module>
# ----> 1 tdf.Time = tdf.Time.astype('datetime64')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
def convetToTime(row):
    if row['IsTime'] == False:
        return row['Time'].time()
    else:
        return row['Time']

# %%
tdf['conTime'] = tdf.apply(convetToTime, axis=1)

# %%
tdf.loc[8156, 'Time'].time()
# Out:
# datetime.time(1, 47)

# %%
tdf[ tdf.IsTime == False]
# Out:
#            Date                 Time PIB rel  PIB pos  PIB count  \
# 189  2020-09-12  1900-01-01 01:16:00  Middle       11         15
# 227  2020-09-03  1900-01-01 00:29:00  Middle       10         20
# 228  2020-09-03  1900-01-01 01:27:00  Middle        8         19
# 292  2020-09-10  1900-01-01 00:26:00  Middle        4         19
# 364  2020-09-15  1900-01-01 01:51:00  Middle       15         18
# ...         ...                  ...     ...      ...        ...
# 7910 2020-09-10  1900-01-01 01:35:00  Middle        3         13
# 7926 2020-09-17  1900-01-01 01:31:00  Middle        4         17
# 8118 2020-09-19  1900-01-01 01:25:00  Middle       15         17
# 8134 2020-09-02  1900-01-01 00:21:00  Middle        9         16
# 8156 2020-09-04  1900-01-01 01:47:00  Middle        4          8
#
#                    Channel                                          Film Code  \
# 189             4FUN DANCE  Skoda octavia/ niebieskie auto/ kreta droga/ n...
# ...

# %%
conToTime2 = lambda row: row['Time'].time() if row['IsTime'] == False else row['Time']

# %%
tdf['conTime2'] = tdf.apply(conToTime2, axis=1)

# %%
tdf
# Out:
#            Date      Time   PIB rel  PIB pos  PIB count   Channel  \
# 0    2020-09-01  17:26:00     First        1         10  13 Ulica
# 1    2020-09-01  18:42:00       2nd        2         11  13 Ulica
# 2    2020-09-01  18:43:00       2nd        2         11  13 Ulica
# 3    2020-09-01  18:44:00       2nd        2         11  13 Ulica
# 4    2020-09-01  18:57:00      Last       11         11  13 Ulica
# ...         ...       ...       ...      ...        ...       ...
# 8218 2020-09-17  21:48:00  2nd last        7          8   Zoom TV
# 8219 2020-09-18  18:20:00    Middle        7          9   Zoom TV
# 8220 2020-09-19  17:27:00    Middle       16         19   Zoom TV
# 8221 2020-09-19  19:26:00    Middle       14         17   Zoom TV
# 8222 2020-09-19  21:35:00    Middle       15         17   Zoom TV
#
#                                               Film Code  \
# 0     Skoda octavia/ niebieskie auto/ kreta droga/ n...
# 1     Skoda octavia/srebrne auto/ kreta droga/ nowa ...
# ...
