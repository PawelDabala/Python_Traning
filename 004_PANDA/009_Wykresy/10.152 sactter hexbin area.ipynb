# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
autos = pd.read_csv("autos.csv", encoding='latin-1')

# %%
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
import re
regex = re.compile('.*toyota.*corolla.*', re.IGNORECASE)
filter1 = autos['name'].apply(lambda x: bool(regex.search(x)))
filter2 = autos['price'] < 12000
filter3 = autos['yearOfRegistration']>=1990
tc = autos[filter1 & filter2 & filter3]

# %%
tc
# Out:
#                 dateCrawled                                          name  \
# 861     2016-03-07 13:46:32                  Toyota_Corolla_1.6_Combi_Sol
# 912     2016-03-27 23:53:18  Toyota_Corolla_Verso_2.2_D_CAT_DPF_Executive
# 1898    2016-03-22 20:52:00                                Toyota_Corolla
# 2264    2016-03-12 23:47:09            Toyota_Corolla_1.6_VVT_i_Combi_Sol
# 2386    2016-03-10 14:48:16            Toyota_Corolla_Verso_2.2_D_CAT_Sol
# ...                     ...                                           ...
# 370220  2016-03-08 19:51:27                            Toyota_Corolla_1.4
# 370878  2016-04-02 07:56:10                Toyota_Corolla_1.4_VVT_i___sol
# 370926  2016-03-11 11:25:24            Top_zuverlaessiger_Toyota_Corolla!
# 371015  2016-03-31 20:53:02                            Toyota_Corolla_1.4
# 371398  2016-04-04 22:48:46             Gepflegter_Toyota_Corolla_1.4.Sol
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 861     privat   Angebot   1800  control       kombi                2003
# 912     privat   Angebot   5300     test         bus                2008
# 1898    privat   Angebot   3200  control  kleinwagen                2004
# 2264    privat   Angebot   2990  control       kombi                2004
# 2386    privat   Angebot   5900     test         bus                2006
# ...        ...       ...    ...      ...         ...                 ...
# 370220  privat   Angebot   3599     test   limousine                2002
# 370878  privat   Angebot   4250     test   limousine                2005
# 370926  privat   Angebot    820     test   limousine                1996
# 371015  privat   Angebot   1300     test       kombi                1997
# 371398  privat   Angebot   3750     test   limousine                2004
#
#         gearbox  powerPS    model  kilometer  monthOfRegistration fuelType  \
# 861     manuell      110  corolla     150000                    6   benzin
# 912     manuell      177    verso     150000                    1   diesel
# 1898    manuell     1398  corolla       5000                    6   benzin
# 2264    manuell      110  corolla     150000                    8   benzin
# 2386    manuell      177    verso     150000                    8   diesel
# ...         ...      ...      ...        ...                  ...      ...
# 370220  manuell       97  corolla     125000                    3   benzin
# 370878  manuell       97  corolla     125000                    7   benzin
# 370926  manuell       75  corolla     150000                   11   benzin
# 371015  manuell       75  corolla     150000                    6   benzin
# 371398  manuell       97  corolla     125000                   11   benzin
#
#          brand notRepairedDamage          dateCreated  nrOfPictures  \
# 861     toyota                ja  2016-03-07 00:00:00             0
# 912     toyota              nein  2016-03-27 00:00:00             0
# 1898    toyota              nein  2016-03-22 00:00:00             0
# 2264    toyota              nein  2016-03-12 00:00:00             0
# 2386    toyota              nein  2016-03-10 00:00:00             0
# ...        ...               ...                  ...           ...
# 370220  toyota              nein  2016-03-08 00:00:00             0
# 370878  toyota              nein  2016-04-02 00:00:00             0
# 370926  toyota              nein  2016-03-11 00:00:00             0
# 371015  toyota              nein  2016-03-31 00:00:00             0
# 371398  toyota              nein  2016-04-04 00:00:00             0
#
#         postalCode             lastSeen
# 861          53347  2016-03-10 10:46:17
# 912          63128  2016-04-06 09:15:32
# 1898         22043  2016-03-22 21:43:26
# 2264         16540  2016-03-31 06:47:04
# 2386         57072  2016-03-14 11:45:36
# ...            ...                  ...
# 370220       51588  2016-03-12 21:20:48
# 370878       84051  2016-04-06 07:15:27
# 370926       35232  2016-03-11 11:25:24
# 371015       50321  2016-03-31 20:53:02
# 371398        1774  2016-04-07 01:45:58
#
# [860 rows x 20 columns]

# %%
import re
regex = re.compile('.*Audi.*a4.*', re.IGNORECASE)
filter1 = autos['name'].apply(lambda x: bool(regex.search(x)))
filter2 = autos['price'] < 12000
filter3 = autos['yearOfRegistration']>=1990
audi = autos[filter1 & filter2 & filter3]

# %%
tc.plot(kind='scatter', x='yearOfRegistration', y='price')
# Out:
# <AxesSubplot:xlabel='yearOfRegistration', ylabel='price'>

# %%
audi.plot(kind='scatter', x='yearOfRegistration', y='price')
# Out:
# <AxesSubplot:xlabel='yearOfRegistration', ylabel='price'>

# %%
ax = audi.plot.scatter(x='yearOfRegistration', y='price', color='Blue', label='Audi')
tc.plot.scatter(x='yearOfRegistration', y='price', color='Green', label='Toyota', ax=ax)
# Out:
# <AxesSubplot:xlabel='yearOfRegistration', ylabel='price'>

# %%
tc.plot.hexbin(x='yearOfRegistration', y='price',gridsize=20, title='Toyota')
audi.plot.hexbin(x='yearOfRegistration', y='price',gridsize=20, title='Audi')
# Out:
# <AxesSubplot:title={'center':'Audi'}, xlabel='yearOfRegistration', ylabel='price'>
