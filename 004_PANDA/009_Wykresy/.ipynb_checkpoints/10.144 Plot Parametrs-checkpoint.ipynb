# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv('weather_barcelona.csv', index_col='Date')

# %%
rom = pd.read_csv('weather_rome.csv', index_col='Date')

# %%
ams = pd.read_csv('weather_amsterdam.csv', index_col='Date')

# %%
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
temp_max = pd.DataFrame(index=  bar.index)

# %%
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']

# %%
temp_max['Amsterdam'] = ams['TempMax']

# %%
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
temp_max.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
temp_max.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
temp_max.plot(figsize=(10,5), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)

# %%
temp_max.plot(figsize=(10,5), use_index=False)
# Out:
# <AxesSubplot:>

# %%
temp_max.plot(figsize=(10,5), title = 'Max temperature by city')
# Out:
# <AxesSubplot:title={'center':'Max temperature by city'}, xlabel='Date'>

# %%
temp_max.plot(figsize=(10,5), legend=False)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
temp_max.plot(figsize=(10,5), logy=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
temp_max[:14].plot(figsize=(10,5), xticks=(range(14)), rot=45 )
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
temp_max[:7].plot(figsize=(10,5), table=True )
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
 import datetime

# %%
 nasa = pd.read_csv("nasa_facebook_statuses.csv",
 usecols=["status_published","num_reactions",
 "num_comments","num_shares","num_likes"])

# %%
#Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])

# %%
 #Select observations between two datetimes - May 2015
filter =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published'] < '2016-6-1')
 nasa = nasa[filter]

# %%
 #Add column with day only
 nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=1)

# %%
#Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum()

# %%
nasa_by_day.head()
# Out:
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
nasa_by_day.plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
nasa_by_day.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='day'>

# %%
nasa_by_day.plot(figsize=(10,5), title='NASA Facebook activity')
# Out:
# <AxesSubplot:title={'center':'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(10,5), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='day'>, <AxesSubplot:xlabel='day'>,
#        <AxesSubplot:xlabel='day'>, <AxesSubplot:xlabel='day'>],
#       dtype=object)

# %%
nasa_by_day.plot(figsize=(10,5), logy=True)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
nasa_by_day.plot(figsize=(10,5), xticks=(range(1, 31)))
# Out:
# <AxesSubplot:xlabel='day'>

# %%
nasa_by_day.plot(figsize=(10,5), xticks=(range(1, 31)), rot=45)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
nasa_by_day[:10].plot(figsize=(10,5), xticks=(range(10)), table=True)
# Out:
# <AxesSubplot:xlabel='day'>
