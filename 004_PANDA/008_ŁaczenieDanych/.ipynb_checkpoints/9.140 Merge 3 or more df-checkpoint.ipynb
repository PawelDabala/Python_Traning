# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd
from datetime import datetime
from datetime import timedelta
import time

# %%
products = pd.read_csv('products.csv', usecols=['ProductID', 'ProductName', 'CategoryID', 'UnitPrice'])

# %%
categories = pd.read_csv('categories1.csv', usecols=['CategoryID', 'CategoryName', 'Description'])

# %%
orders = pd.read_csv('order-details.csv')

# %%
products
# Out:
#     ProductID                      ProductName  CategoryID  UnitPrice
# 0           1                             Chai           1      18.00
# 1           2                            Chang           1      19.00
# 2           3                    Aniseed Syrup           2      10.00
# 3           4     Chef Anton's Cajun Seasoning           2      22.00
# 4           5           Chef Anton's Gumbo Mix           2      21.35
# ..        ...                              ...         ...        ...
# 72         73                       Röd Kaviar           8      15.00
# 73         74                    Longlife Tofu           7      10.00
# 74         75             Rhönbräu Klosterbier           1       7.75
# 75         76                     Lakkalikööri           1      18.00
# 76         77  Original Frankfurter grüne Soße           2      13.00
#
# [77 rows x 4 columns]

# %%
orders
# Out:
#       OrderID  ProductID  UnitPrice  Quantity  Discount
# 0       10248         11      14.00        12      0.00
# 1       10248         42       9.80        10      0.00
# 2       10248         72      34.80         5      0.00
# 3       10249         14      18.60         9      0.00
# 4       10249         51      42.40        40      0.00
# ...       ...        ...        ...       ...       ...
# 2150    11077         64      33.25         2      0.03
# 2151    11077         66      17.00         1      0.00
# 2152    11077         73      15.00         2      0.01
# 2153    11077         75       7.75         4      0.00
# 2154    11077         77      13.00         2      0.00
#
# [2155 rows x 5 columns]

# %%
orders
# Out:
#       OrderID  ProductID  UnitPrice  Quantity  Discount
# 0       10248         11      14.00        12      0.00
# 1       10248         42       9.80        10      0.00
# 2       10248         72      34.80         5      0.00
# 3       10249         14      18.60         9      0.00
# 4       10249         51      42.40        40      0.00
# ...       ...        ...        ...       ...       ...
# 2150    11077         64      33.25         2      0.03
# 2151    11077         66      17.00         1      0.00
# 2152    11077         73      15.00         2      0.01
# 2153    11077         75       7.75         4      0.00
# 2154    11077         77      13.00         2      0.00
#
# [2155 rows x 5 columns]

# %%
cat_prod = products.merge(categories, on='CategoryID')

# %%
cat_prod
# Out:
#     ProductID                    ProductName  CategoryID  UnitPrice  \
# 0           1                           Chai           1      18.00
# 1           2                          Chang           1      19.00
# 2          24             Guaraná Fantástica           1       4.50
# 3          34                  Sasquatch Ale           1      14.00
# 4          35                 Steeleye Stout           1      18.00
# ..        ...                            ...         ...        ...
# 72         42  Singaporean Hokkien Fried Mee           5      14.00
# 73         52                       Filo Mix           5       7.00
# 74         56         Gnocchi di nonna Alice           5      38.00
# 75         57                 Ravioli Angelo           5      19.50
# 76         64      Wimmers gute Semmelknödel           5      33.25
#
#       CategoryName  Description
# 0        Beverages  Soft drinks
# 1        Beverages  Soft drinks
# 2        Beverages  Soft drinks
# ...

# %%
cat_prod.merge(orders, on='ProductID').head()
# Out:
#    ProductID ProductName  CategoryID  UnitPrice_x CategoryName  Description  \
# 0          1        Chai           1         18.0    Beverages  Soft drinks
# 1          1        Chai           1         18.0    Beverages  Soft drinks
# 2          1        Chai           1         18.0    Beverages  Soft drinks
# 3          1        Chai           1         18.0    Beverages  Soft drinks
# 4          1        Chai           1         18.0    Beverages  Soft drinks
#
#    OrderID  UnitPrice_y  Quantity  Discount
# 0    10285         14.4        45      0.20
# 1    10294         14.4        18      0.00
# 2    10317         14.4        20      0.00
# 3    10348         14.4        15      0.15
# 4    10354         14.4        12      0.00

# %%
suppliers = pd.read_csv('suppliers.csv', usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products = pd.read_csv('products.csv', usecols=['ProductID', 'ProductName', 'SupplierID', 'CategoryID'])

# %%
categories = pd.read_csv("categories1.csv",
usecols=['CategoryID','CategoryName'],
index_col="CategoryID")

# %%
products.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID
# 0          1                          Chai           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2

# %%
categories
# Out:
#               CategoryName
# CategoryID
# 1                Beverages
# 2               Condiments
# 3              Confections
# 4           Dairy Products
# 5           Grains/Cereals
# 6             Meat/Poultry
# 7                  Produce
# 8                  Seafood

# %%
prod_cat = products.merge(categories, left_on='CategoryID', right_index=True)

# %%
suppliers
# Out:
#     SupplierID                             CompanyName           City
# 0            1                          Exotic Liquids         London
# 1            2              New Orleans Cajun Delights    New Orleans
# 2            3               Grandma Kelly's Homestead      Ann Arbor
# 3            4                           Tokyo Traders          Tokyo
# 4            5      Cooperativa de Quesos 'Las Cabras'         Oviedo
# 5            6                                Mayumi's          Osaka
# 6            7                            Pavlova Ltd.      Melbourne
# 7            8                 Specialty Biscuits Ltd.     Manchester
# 8            9                        PB Knäckebröd AB       Göteborg
# 9           10               Refrescos Americanas LTDA      Sao Paulo
# 10          11             Heli Süßwaren GmbH & Co. KG         Berlin
# 11          12       Plutzer Lebensmittelgroßmärkte AG      Frankfurt
# ...

# %%
prod_cat.merge(suppliers, on='SupplierID')
# Out:
#     ProductID             ProductName  SupplierID  CategoryID    CategoryName  \
# 0           1                    Chai           1           1       Beverages
# 1           2                   Chang           1           1       Beverages
# 2           3           Aniseed Syrup           1           2      Condiments
# 3          24      Guaraná Fantástica          10           1       Beverages
# 4          34           Sasquatch Ale          16           1       Beverages
# ..        ...                     ...         ...         ...             ...
# 72         48               Chocolade          22           3     Confections
# 73         22     Gustaf's Knäckebröd           9           5  Grains/Cereals
# 74         23                Tunnbröd           9           5  Grains/Cereals
# 75         56  Gnocchi di nonna Alice          26           5  Grains/Cereals
# 76         57          Ravioli Angelo          26           5  Grains/Cereals
#
# ...
