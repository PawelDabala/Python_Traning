# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd
from datetime import datetime
from datetime import timedelta
import time

# %%
categories = pd.read_csv('categories1.csv')
products = pd.read_csv('products.csv')
suppiers = pd.read_csv('suppliers.csv')
customers = pd.read_csv('customers.csv')

# %%
suppliers = pd.read_csv('suppliers.csv', usecols=['SupplierID', 'CompanyName',  'Country'])

# %%
suppiers.columns
# Out:
# Index(['SupplierID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax', 'HomePage'],
#       dtype='object')

# %%
customers = pd.read_csv('customers.csv', usecols=['CustomerID', 'CompanyName',  'Country'])

# %%
customers.head()
# Out:
#   CustomerID                         CompanyName  Country
# 0      ALFKI                 Alfreds Futterkiste  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a   Mexico
# 3      AROUT                     Around the Horn       UK
# 4      BERGS                 Berglunds snabbk?¶p   Sweden

# %%
len(suppliers)
# Out:
# 29

# %%
len(customers)
# Out:
# 91

# %%
df_appended = suppliers.append(customers, ignore_index=True)

# %%
len(df_appended)
# Out:
# 120

# %%
df_appended
# Out:
#      SupplierID                         CompanyName  Country CustomerID
# 0           1.0                      Exotic Liquids       UK        NaN
# 1           2.0          New Orleans Cajun Delights      USA        NaN
# 2           3.0           Grandma Kelly's Homestead      USA        NaN
# 3           4.0                       Tokyo Traders    Japan        NaN
# 4           5.0  Cooperativa de Quesos 'Las Cabras'    Spain        NaN
# ..          ...                                 ...      ...        ...
# 115         NaN                      Wartian Herkku  Finland      WARTH
# 116         NaN              Wellington Importadora   Brazil      WELLI
# 117         NaN                White Clover Markets      USA      WHITC
# 118         NaN                         Wilman Kala  Finland      WILMK
# 119         NaN                      Wolski  Zajazd   Poland      WOLZA
#
# [120 rows x 4 columns]

# %%
suppiers2 = suppliers.copy()

# %%
customers2 = customers.copy()

# %%
suppiers2.rename({'SupplierID': 'CustomerID'}, axis='columns', inplace=True)

# %%
suppiers2.head()
# Out:
#    CustoerID                         CompanyName Country
# 0          1                      Exotic Liquids      UK
# 1          2          New Orleans Cajun Delights     USA
# 2          3           Grandma Kelly's Homestead     USA
# 3          4                       Tokyo Traders   Japan
# 4          5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
suppiers2.rename({'CustoerID': 'CustomerID'}, axis='columns', inplace=True)

# %%
suppiers2.head()
# Out:
#    CustomerID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
suppiers2.append(customers)
# Out:
#    CustomerID                         CompanyName  Country
# 0           1                      Exotic Liquids       UK
# 1           2          New Orleans Cajun Delights      USA
# 2           3           Grandma Kelly's Homestead      USA
# 3           4                       Tokyo Traders    Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'    Spain
# ..        ...                                 ...      ...
# 86      WARTH                      Wartian Herkku  Finland
# 87      WELLI              Wellington Importadora   Brazil
# 88      WHITC                White Clover Markets      USA
# 89      WILMK                         Wilman Kala  Finland
# 90      WOLZA                      Wolski  Zajazd   Poland
#
# [120 rows x 3 columns]

# %%
df_concatenated = pd.concat(objs=[suppliers, customers],ignore_index=True)

# %%
len(df_concatenated)
# Out:
# 120

# %%
df_concatenated.head(40)
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# ...

# %%
mrbean = pd.read_csv('mrbean_facebook_statuses_join.csv', usecols=['status_message_mrbean','status_type','num_likes'])

# %%
nasa = pd.read_csv('nasa_facebook_statuses_join.csv', usecols=['status_message_nasa','status_type','num_likes'])

# %%
mrbean.head()
# Out:
#                                status_message_mrbean status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa.head()
# Out:
#                                  status_message_nasa status_type  num_likes
# 0  This morning, the #RockOn mission with student...       photo       5142
# 1  Pluto's largest moon, Charon, is home to an un...       photo      19074
# 2  Our Restore-L mission is an endeavor to launch...       photo       7551
# 3  A new dark vortex was discovered in the atmosp...       photo      24359
# 4                                                NaN       video       2731

# %%
fb = mrbean.append(nasa, sort=True)

# %%
fb
# Out:
#      num_likes                              status_message_mrbean  \
# 0        16079  It's time for Mr Bean and Teddy to get ready f...
# 1       114008                                                NaN
# 2       218579                                                NaN
# 3        20338  Mr Bean is ready to do some shopping but bewar...
# 4       215591                                                NaN
# ..         ...                                                ...
# 758      39355                                                NaN
# 759      11835                                                NaN
# 760      15567                                                NaN
# 761      41584                                                NaN
# 762      12793                                                NaN
#
#                                    status_message_nasa status_type
# 0                                                  NaN       video
# ...

# %%
fb.loc[0]
# Out:
#    num_likes                              status_message_mrbean  \
# 0      16079  It's time for Mr Bean and Teddy to get ready f...
# 0       5142                                                NaN
#
#                                  status_message_nasa status_type
# 0                                                NaN       video
# 0  This morning, the #RockOn mission with student...       photo

# %%
fb.iloc[0]
# Out:
# num_likes                                                            16079
# status_message_mrbean    It's time for Mr Bean and Teddy to get ready f...
# status_message_nasa                                                    NaN
# status_type                                                          video
# Name: 0, dtype: object

# %%
fb = mrbean.append(nasa, sort=True, ignore_index=True)

# %%
fb
# Out:
#      num_likes                              status_message_mrbean  \
# 0        16079  It's time for Mr Bean and Teddy to get ready f...
# 1       114008                                                NaN
# 2       218579                                                NaN
# 3        20338  Mr Bean is ready to do some shopping but bewar...
# 4       215591                                                NaN
# ..         ...                                                ...
# 814      39355                                                NaN
# 815      11835                                                NaN
# 816      15567                                                NaN
# 817      41584                                                NaN
# 818      12793                                                NaN
#
#                                    status_message_nasa status_type
# 0                                                  NaN       video
# ...

# %%
mrbean.rename({'status_message_mrbean': 'status_message'}, inplace=True)

# %%
mrbean.head()
# Out:
#                                status_message_mrbean status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa.rename({'status_message_nasa': 'status_message'}, inplace=True)

# %%
fb = mrbean.append(nasa, sort=True, ignore_index=True)

# %%
fb
# Out:
#      num_likes                              status_message_mrbean  \
# 0        16079  It's time for Mr Bean and Teddy to get ready f...
# 1       114008                                                NaN
# 2       218579                                                NaN
# 3        20338  Mr Bean is ready to do some shopping but bewar...
# 4       215591                                                NaN
# ..         ...                                                ...
# 814      39355                                                NaN
# 815      11835                                                NaN
# 816      15567                                                NaN
# 817      41584                                                NaN
# 818      12793                                                NaN
#
#                                    status_message_nasa status_type
# 0                                                  NaN       video
# ...

# %%
fb = pd.concat([nasa, mrbean], ignore_index=True)
