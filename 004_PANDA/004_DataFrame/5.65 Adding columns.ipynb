# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd

# %%
frame = pd.read_csv('mcdonalds.csv', usecols=['Item', 'Calories', 'TotalFat', 'Sugars', 'Protein', 'Cholesterol'])

# %%
frame.head()
# Out:
#                                Item  Calories  TotalFat  Cholesterol  Sugars  \
# 0                      Egg McMuffin       300      13.0          260       3
# 1                 Egg White Delight       250       8.0           25       3
# 2                  Sausage McMuffin       370      23.0           45       2
# 3         Sausage McMuffin with Egg       450      28.0          285       2
# 4  Sausage McMuffin with Egg Whites       400      23.0           50       2
#
#    Protein
# 0       17
# 1       18
# 2       14
# 3       21
# 4       21

# %%
frame['TotalFat0'] = 0

# %%
frame.head()
# Out:
#                                Item  Calories  TotalFat  Cholesterol  Sugars  \
# 0                      Egg McMuffin       300      13.0          260       3
# 1                 Egg White Delight       250       8.0           25       3
# 2                  Sausage McMuffin       370      23.0           45       2
# 3         Sausage McMuffin with Egg       450      28.0          285       2
# 4  Sausage McMuffin with Egg Whites       400      23.0           50       2
#
#    Protein  TotalFat0
# 0       17          0
# 1       18          0
# 2       14          0
# 3       21          0
# 4       21          0

# %%
frame["SugarAndFat"] = frame.Sugars + frame.TotalFat
frame.head()
# Out:
#                                Item  Calories  TotalFat  Cholesterol  Sugars  \
# 0                      Egg McMuffin       300      13.0          260       3
# 1                 Egg White Delight       250       8.0           25       3
# 2                  Sausage McMuffin       370      23.0           45       2
# 3         Sausage McMuffin with Egg       450      28.0          285       2
# 4  Sausage McMuffin with Egg Whites       400      23.0           50       2
#
#    Protein  TotalFat0  SugarAndFat
# 0       17          0         16.0
# 1       18          0         11.0
# 2       14          0         25.0
# 3       21          0         30.0
# 4       21          0         25.0

# %%
frame.insert(loc=2, column='SPF', value=frame.Sugars + frame.Protein+frame.TotalFat)

# %%
frame.head()
# Out:
#                                Item  Calories   SPF  TotalFat  Cholesterol  \
# 0                      Egg McMuffin       300  33.0      13.0          260
# 1                 Egg White Delight       250  29.0       8.0           25
# 2                  Sausage McMuffin       370  39.0      23.0           45
# 3         Sausage McMuffin with Egg       450  51.0      28.0          285
# 4  Sausage McMuffin with Egg Whites       400  46.0      23.0           50
#
#    Sugars  Protein  TotalFat0  SugarAndFat
# 0       3       17          0         16.0
# 1       3       18          0         11.0
# 2       2       14          0         25.0
# 3       2       21          0         30.0
# 4       2       21          0         25.0

# %%
del frame['SugarAndFat']

# %%
frame.head()
# Out:
#                                Item  Calories   SPF  TotalFat  Cholesterol  \
# 0                      Egg McMuffin       300  33.0      13.0          260
# 1                 Egg White Delight       250  29.0       8.0           25
# 2                  Sausage McMuffin       370  39.0      23.0           45
# 3         Sausage McMuffin with Egg       450  51.0      28.0          285
# 4  Sausage McMuffin with Egg Whites       400  46.0      23.0           50
#
#    Sugars  Protein  TotalFat0
# 0       3       17          0
# 1       3       18          0
# 2       2       14          0
# 3       2       21          0
# 4       2       21          0

# %%
frame = frame.drop(columns = ['TotalFat0'])

# %%
frame.head()
# Out:
#                                Item  Calories   SPF  TotalFat  Cholesterol  \
# 0                      Egg McMuffin       300  33.0      13.0          260
# 1                 Egg White Delight       250  29.0       8.0           25
# 2                  Sausage McMuffin       370  39.0      23.0           45
# 3         Sausage McMuffin with Egg       450  51.0      28.0          285
# 4  Sausage McMuffin with Egg Whites       400  46.0      23.0           50
#
#    Sugars  Protein
# 0       3       17
# 1       3       18
# 2       2       14
# 3       2       21
# 4       2       21

# %% [markdown]
#  frame.drop(columns=['SPF'], inplace=True)

# %%
frame.head()
# Out:
#                                Item  Calories  TotalFat  Cholesterol  Sugars  \
# 0                      Egg McMuffin       300      13.0          260       3
# 1                 Egg White Delight       250       8.0           25       3
# 2                  Sausage McMuffin       370      23.0           45       2
# 3         Sausage McMuffin with Egg       450      28.0          285       2
# 4  Sausage McMuffin with Egg Whites       400      23.0           50       2
#
#    Protein
# 0       17
# 1       18
# 2       14
# 3       21
# 4       21

# %%
fuel = pd.read_csv('fuel.csv', usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], low_memory=False)

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0

# %%
Combined_KPL = fuel['Combined MPG (FT1)'] * 1.609 / 3.78

# %%
fuel['Combined_KPL'] = Combined_KPL

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)  Combined_KPL
# 0             Minicompact Cars   Regular                20.0      8.513228
# 1             Minicompact Cars   Regular                20.0      8.513228
# 2                  Two Seaters   Regular                21.0      8.938889
# 3                  Two Seaters   Regular                21.0      8.938889
# 4  Special Purpose Vehicle 2WD   Regular                17.0      7.236243

# %%
fuel.insert(loc= 5, column= 'liters per km', value=100 / fuel['Combined_KPL'])

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class  liters per km Fuel Type  Combined MPG (FT1)  \
# 0             Minicompact Cars      11.746426   Regular                20.0
# 1             Minicompact Cars      11.746426   Regular                20.0
# 2                  Two Seaters      11.187073   Regular                21.0
# 3                  Two Seaters      11.187073   Regular                21.0
# 4  Special Purpose Vehicle 2WD      13.819325   Regular                17.0
#
#    Combined_KPL
# 0      8.513228
# 1      8.513228
# 2      8.938889
# 3      8.938889
# 4      7.236243

# %%
del fuel['Combined MPG (FT1)']

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class  liters per km Fuel Type  Combined_KPL
# 0             Minicompact Cars      11.746426   Regular      8.513228
# 1             Minicompact Cars      11.746426   Regular      8.513228
# 2                  Two Seaters      11.187073   Regular      8.938889
# 3                  Two Seaters      11.187073   Regular      8.938889
# 4  Special Purpose Vehicle 2WD      13.819325   Regular      7.236243

# %%
fuel.drop(columns=['Combined_KPL'], inplace=True)

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class  liters per km Fuel Type
# 0             Minicompact Cars      11.746426   Regular
# 1             Minicompact Cars      11.746426   Regular
# 2                  Two Seaters      11.187073   Regular
# 3                  Two Seaters      11.187073   Regular
# 4  Special Purpose Vehicle 2WD      13.819325   Regular

# %%
5
