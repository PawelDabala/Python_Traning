# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd

# %%
frame = pd.read_csv('mcdonalds.csv')

# %%
frame.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'TotalFat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
frame.loc[1, 'TotalFat'] = np.NaN
frame.loc[1, 'Saturated Fat'] = np.NaN
frame.loc[2, 'Saturated Fat'] = np.NaN
frame.loc[3, 'Category'] = np.NaN

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3        NaN         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       NaN                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame.fillna(value=0).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3          0         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       0.0                         12            0.0
# 2                200      23.0                         35            0.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
replaceDefinitionTable = {'Category': 'UNKNOWN', 'TotalFat': 0, 'Saturated Fat': 0}

# %%
replaceDefinitionTable
# Out:
# {'Category': 'UNKNOWN', 'TotalFat': 0, 'Saturated Fat': 0}

# %%
frame.fillna(value=replaceDefinitionTable).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13204/1751588923.py in <module>
# ----> 1 frame.fillna(value=replaceDefinitionTable).head()
#
# NameError: name 'replaceDefinitionTable' is not defined

# %%
frame['Category'].fillna(value='UNKNOWN', inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3    UNKNOWN         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       NaN                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame['TotalFat'].fillna(value=0, inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3    UNKNOWN         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       0.0                         12            NaN
# 2                200      23.0                         35            NaN
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame['Saturated Fat'].fillna(value=0, inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3    UNKNOWN         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       0.0                         12            0.0
# 2                200      23.0                         35            0.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
avgTotalFat = frame['TotalFat'].mean()

# %%
avgTotalFat
# Out:
# 14.18918918918919

# %%
frame['TotalFat'].fillna(value=avgTotalFat, inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3        NaN         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70  14.189189                         12            NaN
# 2                200  23.000000                         35            NaN
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame['Saturated Fat'].fillna(method='ffill', inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3        NaN         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70  14.189189                         12            5.0
# 2                200  23.000000                         35            5.0
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
fuel = pd.read_csv('fuel.csv', usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], low_memory=False, index_col='Vehicle ID')
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550        Regular                17.0

# %%
fuel.loc[27705, 'Class'] = np.NaN
fuel.loc[26561, 'Class'] = np.NaN
fuel.loc[27550, 'Fuel Type'] = np.NaN
fuel.loc[27705, 'Combined MPG (FT1)'] = np.NaN
fuel.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          NaN
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          NaN
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                 NaN
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550            NaN                17.0

# %%
fuel.fillna(value=-1).head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                           -1
# 26561       1984  Alfa Romeo  Spider Veloce 2000                           -1
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                -1.0
# 26561        Regular                21.0
# 27681        Regular                -1.0
# 27550             -1                17.0

# %%
replaceRules = {'Class': '---', 'Fuel Type': '---', 'Combined MPG (FT1)': -1 }
fuel.fillna(replaceRules).head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          ---
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          ---
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                -1.0
# 26561        Regular                21.0
# 27681        Regular                -1.0
# 27550            ---                17.0

# %%
avgMPG = fuel['Combined MPG (FT1)' ].mean()

# %%
avgMPG
# Out:
# 19.444177898424922

# %%
raplaceNan = {'Class': '?', 'Fuel Type': '?', 'Combined MPG (FT1)': avgMPG }

# %%
fuel.fillna(raplaceNan).head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                            ?
# 26561       1984  Alfa Romeo  Spider Veloce 2000                            ?
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular           20.000000
# 27705        Regular           19.444178
# 26561        Regular           21.000000
# 27681        Regular           19.444178
# 27550              ?           17.000000

# %%
fuel['Combined MPG (FT1)'].fillna(method='ffill', inplace=True)

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          NaN
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          NaN
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550            NaN                17.0
