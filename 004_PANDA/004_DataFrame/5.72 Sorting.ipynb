# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd

# %%
frame = pd.read_csv('mcdonalds.csv', usecols=['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'])

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame.sort_values(by='Calories').head()
# Out:
#          Category                    Item  Serving Size  Calories  TotalFat
# 125     Beverages  Diet Dr Pepper (Child)  12 fl oz cup         0       0.0
# 138  Coffee & Tea       Iced Tea (Medium)  21 fl oz cup         0       0.0
# 137  Coffee & Tea        Iced Tea (Small)  16 fl oz cup         0       0.0
# 136     Beverages     Dasani Water Bottle    16.9 fl oz         0       0.0
# 145  Coffee & Tea          Coffee (Small)  12 fl oz cup         0       0.0

# %%
frame['Calories'] = frame['Calories'].astype('float')

# %%
frame.loc[82, 'Calories'] = np.NaN

# %%
frame.loc[82]
# Out:
# Category                      Chicken & Fish
# Item            Chicken McNuggets (40 piece)
# Serving Size                 22.8 oz (646 g)
# Calories                                 NaN
# TotalFat                               118.0
# Name: 82, dtype: object

# %%
frame.sort_values(by='Calories').tail()
# Out:
#           Category                                               Item  \
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  TotalFat
# 33  14.9 oz (423 g)     990.0      46.0
# 34  15.4 oz (437 g)    1050.0      50.0
# 31  14.8 oz (420 g)    1090.0      56.0
# 32  15.3 oz (434 g)    1150.0      60.0
# 82  22.8 oz (646 g)       NaN     118.0

# %%
frame.sort_values(by='Calories', na_position='first').head()
# Out:
#            Category                          Item     Serving Size  Calories  \
# 82   Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)       NaN
# 114       Beverages             Diet Coke (Small)     16 fl oz cup       0.0
# 139    Coffee & Tea              Iced Tea (Large)     30 fl oz cup       0.0
# 138    Coffee & Tea             Iced Tea (Medium)     21 fl oz cup       0.0
# 137    Coffee & Tea              Iced Tea (Small)     16 fl oz cup       0.0
#
#      TotalFat
# 82      118.0
# 114       0.0
# 139       0.0
# 138       0.0
# 137       0.0

# %%
frame.sort_values(by=['Category', 'Item']).head(20)
# Out:
#         Category                                       Item  \
# 51   Beef & Pork                     Bacon Clubhouse Burger
# 53   Beef & Pork                             Bacon McDouble
# 42   Beef & Pork                                    Big Mac
# 49   Beef & Pork                               Cheeseburger
# 54   Beef & Pork                               Daily Double
# 50   Beef & Pork                        Double Cheeseburger
# 47   Beef & Pork         Double Quarter Pounder with Cheese
# 48   Beef & Pork                                  Hamburger
# 55   Beef & Pork                            Jalapeño Double
# 52   Beef & Pork                                   McDouble
# 56   Beef & Pork                                      McRib
# 46   Beef & Pork                     Quarter Pounder Deluxe
# 44   Beef & Pork        Quarter Pounder with Bacon & Cheese
# 45   Beef & Pork  Quarter Pounder with Bacon Habanero Ranch
# 43   Beef & Pork                Quarter Pounder with Cheese
# ...

# %%
frame.sort_values(by=['Category', 'Item'], ascending=[True, False]).head(20)
# Out:
#         Category                                       Item    Serving Size  \
# 43   Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 45   Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 44   Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 46   Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
# 56   Beef & Pork                                      McRib  7.3 oz (208 g)
# 52   Beef & Pork                                   McDouble  5.2 oz (147 g)
# 55   Beef & Pork                            Jalapeño Double  5.6 oz (159 g)
# 48   Beef & Pork                                  Hamburger   3.5 oz (98 g)
# 47   Beef & Pork         Double Quarter Pounder with Cheese   10 oz (283 g)
# 50   Beef & Pork                        Double Cheeseburger  5.7 oz (161 g)
# 54   Beef & Pork                               Daily Double  6.7 oz (190 g)
# ...

# %%
frame = pd.read_csv('mcdonalds.csv', usecols=['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'], index_col='Item')

# %%
frame.head()
# Out:
#                                    Category    Serving Size  Calories  \
# Item
# Egg McMuffin                      Breakfast  4.8 oz (136 g)       300
# Egg White Delight                 Breakfast  4.8 oz (135 g)       250
# Sausage McMuffin                  Breakfast  3.9 oz (111 g)       370
# Sausage McMuffin with Egg         Breakfast  5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites  Breakfast  5.7 oz (161 g)       400
#
#                                   TotalFat
# Item
# Egg McMuffin                          13.0
# Egg White Delight                      8.0
# Sausage McMuffin                      23.0
# Sausage McMuffin with Egg             28.0
# Sausage McMuffin with Egg Whites      23.0

# %%
frame.sort_index(ascending=True).head()
# Out:
#                                      Category       Serving Size  Calories  \
# Item
# 1% Low Fat Milk Jug                 Beverages  1 carton (236 ml)       100
# Apple Slices                   Snacks & Sides      1.2 oz (34 g)        15
# Bacon Buffalo Ranch McChicken  Chicken & Fish     5.7 oz (161 g)       430
# Bacon Cheddar McChicken        Chicken & Fish       6 oz (171 g)       480
# Bacon Clubhouse Burger            Beef & Pork     9.5 oz (270 g)       720
#
#                                TotalFat
# Item
# 1% Low Fat Milk Jug                 2.5
# Apple Slices                        0.0
# Bacon Buffalo Ranch McChicken      21.0
# Bacon Cheddar McChicken            24.0
# Bacon Clubhouse Burger             40.0

# %%
fuel = pd.read_csv('fuel.csv', usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'], low_memory=False, index_col='Vehicle ID')
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550        Regular                17.0

# %%
fuel.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550        Regular                17.0

# %%
fuel.sort_values(by=['Make', 'Model']).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
# 1032        1985  AM General  Post Office DJ5 2WD
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0

# %%
fuel.sort_values(by='Combined MPG (FT1)', ascending=False).head()
# Out:
#             Year        Make           Model             Class    Fuel Type  \
# Vehicle ID
# 31673       2012  Mitsubishi          i-MiEV   Subcompact Cars  Electricity
# 32278       2012        Ford  Focus Electric      Compact Cars  Electricity
# 32276       2011         BMW        Active E   Subcompact Cars  Electricity
# 30979       2011      Nissan            Leaf      Midsize Cars  Electricity
# 30978       2008        MINI           MiniE  Minicompact Cars  Electricity
#
#             Combined MPG (FT1)
# Vehicle ID
# 31673                    112.0
# 32278                    105.0
# 32276                    102.0
# 30979                     99.0
# 30978                     98.0

# %%
fuel.sort_values(by=['Make','Combined MPG (FT1)'], ascending=[True, False]).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 1032        1985  AM General  Post Office DJ5 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0

# %%
fuel.sort_values(by='Combined MPG (FT1)', na_position='first', inplace=True)
fuel.head()
# Out:
#             Year         Make               Model        Class Fuel Type  \
# Vehicle ID
# 27681       1984   Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular
# 32106       2012    Mitsubish                 NaN          NaN       NaN
# 2914        1987  Lamborghini            Countach  Two Seaters   Premium
# 6413        1990  Lamborghini            Countach  Two Seaters   Premium
# 5267        1989  Lamborghini            Countach  Two Seaters   Premium
#
#             Combined MPG (FT1)
# Vehicle ID
# 27681                      NaN
# 32106                      NaN
# 2914                       7.0
# 6413                       7.0
# 5267                       7.0
