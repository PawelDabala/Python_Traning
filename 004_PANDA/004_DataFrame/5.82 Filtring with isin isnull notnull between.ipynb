# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd
frame = pd.read_csv('mcdonalds.csv', usecols=['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'])

# %%
color = ['green', 'green', 'blue', 'blue', 'red', 'red', 'white']
size = ['S', 'S', 'S', 'M', 'M', 'M', 'L']
gender = ['M', 'W', 'M', 'W', 'M', 'W', 'U']
clothes = pd.DataFrame({'color': color, 'size': size, 'gender': gender})
clothes
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 5    red    M      W
# 6  white    L      U

# %%
isColorBlue = clothes.color == 'blue'
isColorGren = clothes.color == 'green'
isColorRed = clothes.color == 'red'
isGenderM = clothes.gender == 'M'
isGenderW = clothes.gender == 'W'
isSizeS = clothes['size'] == 'S'
isSizeM = clothes['size'] == 'M'

# %%
myColors = clothes.color.isin(['blue', 'green', 'red'])
clothes[myColors]
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 5    red    M      W

# %%
clothes.loc[6, 'size'] = np.NaN

# %%
clothes
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 5    red    M      W
# 6  white  NaN      U

# %%
clothes['size'].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# Name: size, dtype: bool

# %%
hasSize = clothes['size'].notnull()
clothes[hasSize]
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 5    red    M      W

# %%
clothes['size'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: size, dtype: bool

# %%
siezeUnknown = clothes['size'].isnull()

# %%
clothes[siezeUnknown]
# Out:
#    color size gender
# 6  white  NaN      U

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
hasMoreThen300Cal = frame.Calories >=300
hasLessThen400Cal = frame.Calories <=400

# %%
frame[hasMoreThen300Cal & hasLessThen400Cal].head()
# Out:
#      Category                                            Item    Serving Size  \
# 0   Breakfast                                    Egg McMuffin  4.8 oz (136 g)
# 2   Breakfast                                Sausage McMuffin  3.9 oz (111 g)
# 4   Breakfast                Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 20  Breakfast  Bacon, Egg & Cheese McGriddles with Egg Whites  6.3 oz (178 g)
# 35  Breakfast                                        Hotcakes  5.3 oz (151 g)
#
#     Calories  TotalFat
# 0        300      13.0
# 2        370      23.0
# 4        400      23.0
# 20       400      15.0
# 35       350       9.0

# %%
CaloriesBetween300and400 = frame.Calories.between(300, 400)

# %%
frame[CaloriesBetween300and400]
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 2             Breakfast                                   Sausage McMuffin
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 20            Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 35            Breakfast                                           Hotcakes
# 37            Breakfast                                    Sausage Burrito
# 52          Beef & Pork                                           McDouble
# 58       Chicken & Fish           Premium Grilled Chicken Classic Sandwich
# 66       Chicken & Fish                                          McChicken
# 69       Chicken & Fish                            Buffalo Ranch McChicken
# 77       Chicken & Fish  Premium McWrap Chicken Sweet Chili (Grilled Ch...
# ...

# %%
fuel = pd.read_csv('fuel.csv', low_memory=False, usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)','Start Stop Technology'])
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)  \
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0
#
#   Start Stop Technology
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
listOfCars = ['Renault', 'Toyota','Ford']
isInList = fuel.Make.isin(listOfCars)
isInList.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Make, dtype: bool

# %%
fuel[isInList]
# Out:
#        Vehicle ID  Year  Make                      Model  \
# 668         27613  1984  Ford                 Bronco 4WD
# 669         27616  1984  Ford                 Bronco 4WD
# 670         27619  1984  Ford                 Bronco 4WD
# 671         27622  1984  Ford                 Bronco 4WD
# 672         28472  1984  Ford                 Bronco 4WD
# ...           ...   ...   ...                        ...
# 31266       31786  2012  Ford                 Taurus AWD
# 31267       31784  2012  Ford                 Taurus FWD
# 31268       31785  2012  Ford                 Taurus FWD
# 31269       31458  2012  Ford        Transit Connect Van
# 31270       31460  2012  Ford  Transit Connect Wagon FWD
#
#                              Class Fuel Type  Combined MPG (FT1)  \
# 668    Special Purpose Vehicle 4WD   Regular                13.0
# 669    Special Purpose Vehicle 4WD   Regular                11.0
# 670    Special Purpose Vehicle 4WD   Regular                10.0
# ...

# %%
isNoStartStopDefined = fuel["Start Stop Technology"].isnull()

# %%
isNoStartStopDefined.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Start Stop Technology, dtype: bool

# %%
fuel[isNoStartStopDefined].head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)  \
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0
#
#   Start Stop Technology
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
isStartStopDefined = fuel["Start Stop Technology"].notnull()
fuel[isStartStopDefined].head()
# Out:
#        Vehicle ID  Year       Make                      Model  \
# 16448       30976  1998  Chevrolet               S10 Electric
# 16449       30977  1998  Chevrolet               S10 Electric
# 16711       30975  1998      Honda                    EV Plus
# 17323       30973  1999      Dodge  Caravan/Grand Caravan 2WD
# 17433       30971  1999       Ford          Ranger Pickup 2WD
#
#                             Class    Fuel Type  Combined MPG (FT1)  \
# 16448     Small Pickup Trucks 2WD  Electricity                55.0
# 16449     Small Pickup Trucks 2WD  Electricity                28.0
# 16711                Compact Cars  Electricity                48.0
# 17323               Minivan - 2WD  Electricity                35.0
# 17433  Standard Pickup Trucks 2WD  Electricity                58.0
#
#       Start Stop Technology
# 16448                     N
# 16449                     N
# 16711                     N
# 17323                     N
# 17433                     N

# %%
mpg50_60 = fuel["Combined MPG (FT1)"].between(50, 60)
mpg50_60.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Combined MPG (FT1), dtype: bool

# %%
fuel[mpg50_60]
# Out:
#        Vehicle ID  Year       Make              Model  \
# 16448       30976  1998  Chevrolet       S10 Electric
# 17433       30971  1999       Ford  Ranger Pickup 2WD
# 18295       30966  2000       Ford  Ranger Pickup 2WD
# 18296       30967  2000       Ford  Ranger Pickup 2WD
# 18371       15606  2000      Honda            Insight
# 19162       30965  2001       Ford  Ranger Pickup 2WD
# 19240       16447  2001      Honda            Insight
# 20178       17355  2002      Honda            Insight
# 21192       18313  2003      Honda            Insight
# 22264       19357  2004      Honda            Insight
# 23392       20479  2005      Honda            Insight
# 24522       21632  2006      Honda            Insight
# 29643       26425  2010     Toyota              Prius
#
#                             Class    Fuel Type  Combined MPG (FT1)  \
# 16448     Small Pickup Trucks 2WD  Electricity                55.0
# 17433  Standard Pickup Trucks 2WD  Electricity                58.0
# ...

# %%
f'There are {len(fuel[isInList])} cars within the list {listOfCars}'
# Out:
# 'There are 31374 cars where Start/Stop technology is not determined'

# %%
f'There are {len(fuel[isNoStartStopDefined])} cars where Start/Stop technology is not determined'
# Out:
# 'There are 31374 cars where Start/Stop technology is not determined'

# %%
f'There are {len(fuel[isStartStopDefined])} cars where Start/Stop technology is determined'
# Out:
# 'There are 310 cars where Start/Stop technology is determined'

# %%
f'There are {len(fuel[mpg50_60])} cares with MPG value between 50 and 60'
# Out:
# 'There are 13 cares with MPG value between 50 and 60'
