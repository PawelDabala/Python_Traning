# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd

# %%
sales = pd.read_csv('WA_Sales_Products_2012-14.csv')

# %%
sales.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# 3       303      0.282938
# 4      1415      0.291450

# %%
pt = sales.pivot_table(index='Retailer country', columns='Year', values='Revenue', aggfunc='sum').head()

# %%
pt.reset_index(inplace=True)
pt.head()
# Out:
# Year Retailer country         2012         2013         2014
# 0           Australia  25607043.50  47799737.14  35893188.50
# 1             Austria  34568089.63  44996737.04  33801788.98
# 2             Belgium  30396297.49  38375432.68  28186839.74
# 3              Brazil  34234876.30  43389953.66  31440841.48
# 4              Canada  75428386.09  98134069.39  73325209.39

# %%
pt.fillna(0, inplace=True)
pt.head()
# Out:
# Year Retailer country         2012         2013         2014
# 0           Australia  25607043.50  47799737.14  35893188.50
# 1             Austria  34568089.63  44996737.04  33801788.98
# 2             Belgium  30396297.49  38375432.68  28186839.74
# 3              Brazil  34234876.30  43389953.66  31440841.48
# 4              Canada  75428386.09  98134069.39  73325209.39

# %%
pt.melt(id_vars='Retailer country', value_name='RevenueSum', var_name='YearOfTransaction').head()
# Out:
#   Retailer country YearOfTransaction   RevenueSum
# 0        Australia              2012  25607043.50
# 1          Austria              2012  34568089.63
# 2          Belgium              2012  30396297.49
# 3           Brazil              2012  34234876.30
# 4           Canada              2012  75428386.09

# %%
pt.melt(id_vars='Retailer country', value_name='RevenueSum', var_name='YearOfTransaction', value_vars=[2013, 2014]).head()
# Out:
#   Retailer country YearOfTransaction   RevenueSum
# 0        Australia              2013  47799737.14
# 1          Austria              2013  44996737.04
# 2          Belgium              2013  38375432.68
# 3           Brazil              2013  43389953.66
# 4           Canada              2013  98134069.39

# %%
from datetime import datetime
from datetime import timedelta
import time

# %%
df = pd.read_csv('marathon_results_2016.csv', index_col='Bib', usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])
df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)
df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))
df = df.pivot_table(index="Age",columns="M/F",values="TotalSeconds").head()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21920/3026407839.py in <module>
#       1 df = pd.read_csv('marathon_results_2016.csv', index_col='Bib', usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])
# ----> 2 df['40K'] = df['40K'].apply(pd.to_timedelta)
#       3 df['Half'] = df['Half'].apply(pd.to_timedelta)
#       4 df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
#       5 df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in to_timedelta(arg, unit, errors)
#     140
#     141     # ...so it must be a scalar value. Return scalar.
# --> 142     return _coerce_scalar_to_timedelta_type(arg, unit=unit, errors=errors)
#     143
#     144
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in _coerce_scalar_to_timedelta_type(r, unit, errors)
#     148
#     149     try:
# --> 150         result = Timedelta(r, unit)
#     151     except ValueError:
#     152         if errors == "raise":
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: symbols w/o a number

# %%
df = pd.read_csv('marathon_results_2016.csv', index_col='Bib', usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])

# %%
df = pd.read_csv('marathon_results_2016.csv', index_col='Bib', usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])
df['40K'] = df['40K'].apply(pd.to_timedelta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21920/409990109.py in <module>
#       1 df = pd.read_csv('marathon_results_2016.csv', index_col='Bib', usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])
# ----> 2 df['40K'] = df['40K'].apply(pd.to_timedelta)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in to_timedelta(arg, unit, errors)
#     140
#     141     # ...so it must be a scalar value. Return scalar.
# --> 142     return _coerce_scalar_to_timedelta_type(arg, unit=unit, errors=errors)
#     143
#     144
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in _coerce_scalar_to_timedelta_type(r, unit, errors)
#     148
#     149     try:
# --> 150         result = Timedelta(r, unit)
#     151     except ValueError:
#     152         if errors == "raise":
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: symbols w/o a number
