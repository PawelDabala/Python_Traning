# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd

# %%
frame = pd.read_csv('sleep_time.csv', index_col='ID')

# %%
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 1          12.1        NaN          NaN   11.9      NaN   50.000
# 2          17.0        1.8          NaN    7.0  0.01550    0.480
# 3          14.4        2.4          NaN    9.6      NaN    1.350
# 4          14.9        2.3     0.133333    9.1  0.00029    0.019
# 5           4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
frame.drop(axis=0, labels = [1,2], inplace=True)
frame.head()
# Out:
#                           name        genus   vore         order  \
# ID
# 3              Mountain beaver   Aplodontia  herbi      Rodentia
# 4   Greater short-tailed shrew      Blarina   omni  Soricomorpha
# 5                          Cow          Bos  herbi  Artiodactyla
# 6             Three-toed sloth     Bradypus  herbi        Pilosa
# 7            Northern fur seal  Callorhinus  carni     Carnivora
#
#     conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 3             nt         14.4        2.4          NaN    9.6      NaN    1.350
# 4             lc         14.9        2.3     0.133333    9.1  0.00029    0.019
# 5   domesticated          4.0        0.7     0.666667   20.0  0.42300  600.000
# 6            NaN         14.4        2.2     0.766667    9.6      NaN    3.850
# 7             vu          8.7        1.4     0.383333   15.3      NaN   20.490

# %%
frame.drop(axis='rows', labels=3, inplace=True)

# %%
frame.head()
# Out:
#                           name        genus   vore         order  \
# ID
# 4   Greater short-tailed shrew      Blarina   omni  Soricomorpha
# 5                          Cow          Bos  herbi  Artiodactyla
# 6             Three-toed sloth     Bradypus  herbi        Pilosa
# 7            Northern fur seal  Callorhinus  carni     Carnivora
# 8                 Vesper mouse      Calomys    NaN      Rodentia
#
#     conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 4             lc         14.9        2.3     0.133333    9.1  0.00029    0.019
# 5   domesticated          4.0        0.7     0.666667   20.0  0.42300  600.000
# 6            NaN         14.4        2.2     0.766667    9.6      NaN    3.850
# 7             vu          8.7        1.4     0.383333   15.3      NaN   20.490
# 8            NaN          7.0        NaN          NaN   17.0      NaN    0.045

# %%
frame.drop(labels=4, inplace=True)

# %%
frame.head()
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 5                 Cow          Bos  herbi  Artiodactyla  domesticated
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 5           4.0        0.7     0.666667   20.0    0.423  600.000
# 6          14.4        2.2     0.766667    9.6      NaN    3.850
# 7           8.7        1.4     0.383333   15.3      NaN   20.490
# 8           7.0        NaN          NaN   17.0      NaN    0.045
# 9          10.1        2.9     0.333333   13.9    0.070   14.000

# %%
frame.drop(5, inplace=True)

# %%
frame.head()
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 6          14.4        2.2     0.766667    9.6      NaN   3.850
# 7           8.7        1.4     0.383333   15.3      NaN  20.490
# 8           7.0        NaN          NaN   17.0      NaN   0.045
# 9          10.1        2.9     0.333333   13.9   0.0700  14.000
# 10          3.0        NaN          NaN   21.0   0.0982  14.800

# %%
frame.append({'name': 'Panda4', 'genus': np.NaN}, ignore_index=True)
# Out:
#                     name        genus   vore         order  conservation  \
# 0       Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 1      Northern fur seal  Callorhinus  carni     Carnivora            vu
# 2           Vesper mouse      Calomys    NaN      Rodentia           NaN
# 3                    Dog        Canis  carni     Carnivora  domesticated
# 4               Roe deer    Capreolus  herbi  Artiodactyla            lc
# ..                   ...          ...    ...           ...           ...
# 74  Bottle-nosed dolphin     Tursiops  carni       Cetacea           NaN
# 75                 Genet      Genetta  carni     Carnivora           NaN
# 76            Arctic fox       Vulpes  carni     Carnivora           NaN
# 77               Red fox       Vulpes  carni     Carnivora           NaN
# 78                Panda4          NaN    NaN           NaN           NaN
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ...

# %%
subset = frame[0:5]

# %%
subset
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 6          14.4        2.2     0.766667    9.6      NaN   3.850
# 7           8.7        1.4     0.383333   15.3      NaN  20.490
# 8           7.0        NaN          NaN   17.0      NaN   0.045
# 9          10.1        2.9     0.333333   13.9   0.0700  14.000
# 10          3.0        NaN          NaN   21.0   0.0982  14.800

# %%
frame.append(subset)
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
# ..                ...          ...    ...           ...           ...
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# ...

# %%
professions = pd.read_csv("Prestige.csv")
professions.head()
# Out:
#                   name  education  income  women  prestige  census  type
# 0   gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1     general.managers      12.26   25879   4.02      69.1    1130  prof
# 2          accountants      12.77    9271  15.70      63.4    1171  prof
# 3  purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4             chemists      14.62    8403  11.68      73.5    2111  prof

# %%
new_row = {"name": 'data scientist'}
professions =  professions.append(new_row, ignore_index=True)

# %%
professions
# Out:
#                     name  education   income  women  prestige  census  type
# 0     gov.administrators      13.11  12351.0  11.16      68.8  1113.0  prof
# 1       general.managers      12.26  25879.0   4.02      69.1  1130.0  prof
# 2            accountants      12.77   9271.0  15.70      63.4  1171.0  prof
# 3    purchasing.officers      11.42   8865.0   9.11      56.8  1175.0  prof
# 4               chemists      14.62   8403.0  11.68      73.5  2111.0  prof
# ..                   ...        ...      ...    ...       ...     ...   ...
# 98          taxi.drivers       7.93   4224.0   3.59      25.1  9173.0    bc
# 99          longshoremen       8.37   4753.0   0.00      26.1  9313.0    bc
# 100          typesetters      10.00   6462.0  13.58      42.2  9511.0    bc
# 101          bookbinders       8.55   3617.0  70.87      35.2  9517.0    bc
# 102       data scientist        NaN      NaN    NaN       NaN     NaN   NaN
#
# [103 rows x 7 columns]

# %%
taxi = professions.name == 'taxi.drivers'
taxi = professions[taxi]

# %%
taxi
# Out:
#             name  education  income  women  prestige  census type
# 98  taxi.drivers       7.93  4224.0   3.59      25.1  9173.0   bc

# %%
professions.drop(98, inplace=True)

# %%
professions.tail()
# Out:
#                name  education  income  women  prestige  census type
# 97      bus.drivers       7.58  5562.0   9.47      35.9  9171.0   bc
# 99     longshoremen       8.37  4753.0   0.00      26.1  9313.0   bc
# 100     typesetters      10.00  6462.0  13.58      42.2  9511.0   bc
# 101     bookbinders       8.55  3617.0  70.87      35.2  9517.0   bc
# 102  data scientist        NaN     NaN    NaN       NaN     NaN  NaN

# %%
professions = professions.append(taxi)
professions.tail()
# Out:
#                name  education  income  women  prestige  census type
# 99     longshoremen       8.37  4753.0   0.00      26.1  9313.0   bc
# 100     typesetters      10.00  6462.0  13.58      42.2  9511.0   bc
# 101     bookbinders       8.55  3617.0  70.87      35.2  9517.0   bc
# 102  data scientist        NaN     NaN    NaN       NaN     NaN  NaN
# 98     taxi.drivers       7.93  4224.0   3.59      25.1  9173.0   bc

# %%
professions.drop(columns='census', inplace=True)

# %%
professions.head()
# Out:
#                   name  education   income  women  prestige  type
# 0   gov.administrators      13.11  12351.0  11.16      68.8  prof
# 1     general.managers      12.26  25879.0   4.02      69.1  prof
# 2          accountants      12.77   9271.0  15.70      63.4  prof
# 3  purchasing.officers      11.42   8865.0   9.11      56.8  prof
# 4             chemists      14.62   8403.0  11.68      73.5  prof

# %%
del professions['type']

# %%
professions.head()
# Out:
#                   name  education   income  women  prestige
# 0   gov.administrators      13.11  12351.0  11.16      68.8
# 1     general.managers      12.26  25879.0   4.02      69.1
# 2          accountants      12.77   9271.0  15.70      63.4
# 3  purchasing.officers      11.42   8865.0   9.11      56.8
# 4             chemists      14.62   8403.0  11.68      73.5
